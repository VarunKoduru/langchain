# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunKoduru/langchain/blob/main/Langchain_Prac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip install -q --upgrade langchain-core langchain-community requests==2.32.4

# %%
# Document Loaders in Langchain
from langchain_community.document_loaders import TextLoader

loader = TextLoader('/content/langchain.txt',encoding='utf-8')

docs = loader.load()

print(type(docs))
print(docs[0])
print(docs[0].page_content)
print(docs[0].metadata)
# Out:
# <class 'list'>
# page_content='LangChain is an open-source framework designed to simplify the development of applications powered by large language models (LLMs). It provides developers with a structured way to build intelligent applications that can understand, generate, and process natural language. Rather than interacting with a language model directly, LangChain offers reusable components that help manage prompts, memory, external data sources, and workflows, making it easier to create scalable AI solutions.
#
# One of the key features of LangChain is its ability to connect language models with external tools and data. It allows applications to retrieve information from databases, documents, APIs, and websites, enabling language models to generate responses based on up-to-date and domain-specific information. This approach, often called Retrieval-Augmented Generation (RAG), improves the accuracy and relevance of AI-generated responses while reducing the chances of producing incorrect or outdated information.
#
# LangChain also supports the creation of AI agents that can perform complex tasks by making decisions, using tools, and executing multiple steps to achieve a goal. These agents can interact with search engines, calculators, file systems, and other software services to solve problems beyond simple text generation. Developers can define workflows that combine reasoning, tool usage, and user interaction, making applications more dynamic and capable.
#
# Another important capability of LangChain is memory management. It enables applications to maintain context across multiple interactions, allowing chatbots and virtual assistants to remember previous conversations and provide more personalized responses. This improves the user experience by making conversations more natural and coherent, especially in customer support, education, and productivity applications.
#
#
# ' metadata={'source': '/content/langchain.txt'}
# LangChain is an open-source framework designed to simplify the development of applications powered by large language models (LLMs). It provides developers with a structured way to build intelligent applications that can understand, generate, and process natural language. Rather than interacting with a language model directly, LangChain offers reusable components that help manage prompts, memory, external data sources, and workflows, making it easier to create scalable AI solutions.
#
# One of the key features of LangChain is its ability to connect language models with external tools and data. It allows applications to retrieve information from databases, documents, APIs, and websites, enabling language models to generate responses based on up-to-date and domain-specific information. This approach, often called Retrieval-Augmented Generation (RAG), improves the accuracy and relevance of AI-generated responses while reducing the chances of producing incorrect or outdated information.
#
# LangChain also supports the creation of AI agents that can perform complex tasks by making decisions, using tools, and executing multiple steps to achieve a goal. These agents can interact with search engines, calculators, file systems, and other software services to solve problems beyond simple text generation. Developers can define workflows that combine reasoning, tool usage, and user interaction, making applications more dynamic and capable.
#
# Another important capability of LangChain is memory management. It enables applications to maintain context across multiple interactions, allowing chatbots and virtual assistants to remember previous conversations and provide more personalized responses. This improves the user experience by making conversations more natural and coherent, especially in customer support, education, and productivity applications.
#
#
#
# {'source': '/content/langchain.txt'}

# %%
# !pip install -qU \
langchain \
langchain-community \
langchain-core \
langchain-google-genai \
langsmith

# %%
pip install -r "/content/requirements.txt"
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 2)) (1.3.11)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 3)) (1.4.8)
# Collecting langchain-openai (from -r /content/requirements.txt (line 6))
#   Downloading langchain_openai-1.3.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 7)) (2.43.0)
# Collecting langchain-anthropic (from -r /content/requirements.txt (line 10))
#   Downloading langchain_anthropic-1.4.8-py3-none-any.whl.metadata (3.5 kB)
# Collecting langchain-google-genai (from -r /content/requirements.txt (line 13))
#   Downloading langchain_google_genai-4.2.7-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 14)) (0.8.6)
# Collecting langchain-huggingface (from -r /content/requirements.txt (line 17))
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 18)) (5.12.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 19)) (1.20.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 22)) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 25)) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/requirements.txt (line 26)) (1.6.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (0.9.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r /content/requirements.txt (line 3)) (0.16.2)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai->-r /content/requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/requirements.txt (line 7)) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/requirements.txt (line 7)) (4.67.3)
# Collecting anthropic<1.0.0,>=0.96.0 (from langchain-anthropic->-r /content/requirements.txt (line 10))
#   Downloading anthropic-0.116.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->-r /content/requirements.txt (line 13))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai->-r /content/requirements.txt (line 13)) (2.10.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai->-r /content/requirements.txt (line 14)) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai->-r /content/requirements.txt (line 14)) (2.30.3)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai->-r /content/requirements.txt (line 14)) (2.197.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai->-r /content/requirements.txt (line 14)) (2.49.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai->-r /content/requirements.txt (line 14)) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->-r /content/requirements.txt (line 14)) (1.28.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface->-r /content/requirements.txt (line 17)) (0.22.2)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/requirements.txt (line 18)) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/requirements.txt (line 18)) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/requirements.txt (line 18)) (0.8.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r /content/requirements.txt (line 19)) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r /content/requirements.txt (line 19)) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r /content/requirements.txt (line 19)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r /content/requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/requirements.txt (line 26)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/requirements.txt (line 26)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/requirements.txt (line 26)) (3.6.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic->-r /content/requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai->-r /content/requirements.txt (line 7)) (3.18)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai->-r /content/requirements.txt (line 14)) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai->-r /content/requirements.txt (line 14)) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai->-r /content/requirements.txt (line 14)) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai->-r /content/requirements.txt (line 14)) (49.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai->-r /content/requirements.txt (line 14)) (4.9.1)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r /content/requirements.txt (line 13)) (15.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai->-r /content/requirements.txt (line 7)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai->-r /content/requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r /content/requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r /content/requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r /content/requirements.txt (line 2)) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r /content/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r /content/requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r /content/requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r /content/requirements.txt (line 3)) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r /content/requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r /content/requirements.txt (line 3)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/requirements.txt (line 2)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->-r /content/requirements.txt (line 18)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->-r /content/requirements.txt (line 18)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->-r /content/requirements.txt (line 18)) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai->-r /content/requirements.txt (line 14)) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai->-r /content/requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai->-r /content/requirements.txt (line 14)) (4.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai->-r /content/requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->-r /content/requirements.txt (line 14)) (1.81.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->-r /content/requirements.txt (line 14)) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->-r /content/requirements.txt (line 14)) (3.3.2)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain->-r /content/requirements.txt (line 2)) (1.12.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->-r /content/requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai->-r /content/requirements.txt (line 14)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai->-r /content/requirements.txt (line 14)) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers->-r /content/requirements.txt (line 18)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers->-r /content/requirements.txt (line 18)) (2.20.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai->-r /content/requirements.txt (line 14)) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers->-r /content/requirements.txt (line 18)) (0.1.2)
# Downloading langchain_openai-1.3.3-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 5.0 MB/s eta 0:00:00
# Downloading langchain_anthropic-1.4.8-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 5.1 MB/s eta 0:00:00
# Downloading langchain_google_genai-4.2.7-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 7.5 MB/s eta 0:00:00
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Downloading anthropic-0.116.0-py3-none-any.whl (956 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.9/956.9 kB 32.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: filetype, anthropic, langchain-openai, langchain-anthropic, langchain-huggingface, langchain-google-genai
# Successfully installed anthropic-0.116.0 filetype-1.2.0 langchain-anthropic-1.4.8 langchain-google-genai-4.2.7 langchain-huggingface-1.2.2 langchain-openai-1.3.3

# %%
import langchain

print(langchain.__version__)
# Out:
# 1.3.11
